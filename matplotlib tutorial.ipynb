# %%
import matplotlib.pyplot as plt

# %%
x = [5,2,7]

# %%
y = [2,16,4]

# %%
plt.plot(x,y)

# %%
plt.title('Matplot lib graph')
# Out:
# Text(0.5,1,'Matplot lib graph')

# %%
plt.ylabel('Y axis')
# Out:
# Text(0,0.5,'Y axis')

# %%
plt.xlabel('X axis')
# Out:
# Text(0.5,0,'X axis')

# %%
plt.show()

# %%
plt.plot(x,y)

# %%
plt.title('Matplot lib graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.plot(x,y)
plt.title('Matplot lib graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %% [markdown]
# you can have bar, scatter plot, stackplot, pie plot .. check this out
