# %% [markdown]
# # Yield Prediction for Airbnb Portland

# %%
import pandas as pd
import os
import re
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
sns.set(style="ticks")
np.random.seed(sum(map(ord, "axis_grids")))
pd.options.display.max_columns = 20

# %% [markdown]
# read data

# %%
df = pd.read_csv("portland_listings_detailed.csv", header=0, index_col=0)
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 4944 rows, 95 columns.

# %%
df.head()
# Out:
#                               listing_url       scrape_id last_scraped  \
# id
# 7893    https://www.airbnb.com/rooms/7893  20180710033353   2018-07-10
# 12899  https://www.airbnb.com/rooms/12899  20180710033353   2018-07-10
# 16688  https://www.airbnb.com/rooms/16688  20180710033353   2018-07-10
# 25200  https://www.airbnb.com/rooms/25200  20180710033353   2018-07-10
# 26203  https://www.airbnb.com/rooms/26203  20180710033353   2018-07-10
#
#                                                     name  \
# id
# 7893                            North Williams 2brm Home
# 12899  Alberta Arts 2 bedroom suite, charming 1906 house
# 16688     Beautiful condo in downtown Pearl, NW Portland
# 25200             Flamenco Dream :: hip mississippi ave.
# 26203                     Bluebird @ hip mississippi ave
#
#                                                  summary  \
# id
# 7893   Located on Williams bike corridor, some of Por...
# 12899  Settle in to a space of your own. You'll have ...
# 16688  Newly remodeled 2 bedroom (3 queen beds), 2 fu...
# 25200  If you are an Urban Farming pioneer, enthusias...
# 26203  If you are an Urban Farming pioneer, enthusias...
#
#                                                    space  \
# id
# 7893   This NE Portland 2 bedroom home is located jus...
# 12899  We live in a neighborhood of beautiful gardens...
# 16688  - Fully furnished condo with high ceilings, bi...
# 25200  The large farmhouse is surrounded by magical u...
# 26203  The large farmhouse is surrounded by magical u...
#
#                                              description experiences_offered  \
# id
# 7893   Located on Williams bike corridor, some of Por...                none
# 12899  Settle in to a space of your own. You'll have ...                none
# 16688  Newly remodeled 2 bedroom (3 queen beds), 2 fu...                none
# 25200  If you are an Urban Farming pioneer, enthusias...                none
# 26203  If you are an Urban Farming pioneer, enthusias...                none
#
#                                    neighborhood_overview  \
# id
# 7893                                                 NaN
# 12899  We're within walking distance of a grocery and...
# 16688  Easily one of Portland’s most desirable neighb...
# 25200  Tierra Soul is located in the fun and hip Miss...
# 26203  We are located in the fun and hip Mississippi ...
#
#                                                    notes        ...         \
# id                                                              ...
# 7893                                                 NaN        ...
# 12899  We welcome musicians and even have a guitar fo...        ...
# 16688  - Smoking is strictly prohibited - Must be abl...        ...
# 25200  QUIET HOURS: (9pm -7am) We have guests from al...        ...
# 26203  QUIET HOURS: (9pm -7am) We have guests from al...        ...
#
#       requires_license                license  \
# id
# 7893                 t                    NaN
# 12899                t    14-218887-000-00-HO
# 16688                t  2008-190040-000-00-RS
# 25200                t                    NaN
# 26203                t                    NaN
#
#                       jurisdiction_names instant_bookable  \
# id
# 7893   {OREGON," MULTNOMAH"," PORTLAND"}                f
# 12899  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 16688  {OREGON," MULTNOMAH"," PORTLAND"}                t
# 25200  {OREGON," MULTNOMAH"," PORTLAND"}                f
# 26203  {OREGON," MULTNOMAH"," PORTLAND"}                f
#
#        is_business_travel_ready          cancellation_policy  \
# id
# 7893                          f                     flexible
# 12899                         f                     moderate
# 16688                         f                     moderate
# 25200                         f  strict_14_with_grace_period
# 26203                         f  strict_14_with_grace_period
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# id
# 7893                              f                                 f
# 12899                             f                                 f
# 16688                             f                                 f
# 25200                             f                                 f
# 26203                             f                                 f
#
#        calculated_host_listings_count reviews_per_month
# id
# 7893                                1              0.02
# 12899                               1              4.64
# 16688                               1              1.92
# 25200                               4              0.29
# 26203                               4              0.26
#
# [5 rows x 95 columns]

# %% [markdown]
# # Data Exploration

# %%
#Keep selected features

cols_to_keep = [
    'description', 
    'property_type', 'room_type', 'accommodates',
    'bathrooms', 'bedrooms', 'beds', 'square_feet',
    'price', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
    'availability_365', 'reviews_per_month', 'latitude', 'longitude', 'bed_type'
]

# %%
df = df[cols_to_keep]
print("Dataset has {} rows, {} columns.".format(*df.shape))
df.head()
# Out:
# Dataset has 4944 rows, 18 columns.
#                                              description property_type  \
# id
# 7893   Located on Williams bike corridor, some of Por...         House
# 12899  Settle in to a space of your own. You'll have ...   Guest suite
# 16688  Newly remodeled 2 bedroom (3 queen beds), 2 fu...         House
# 25200  If you are an Urban Farming pioneer, enthusias...         House
# 26203  If you are an Urban Farming pioneer, enthusias...         House
#
#              room_type  accommodates  bathrooms  bedrooms  beds  square_feet  \
# id
# 7893   Entire home/apt             3        1.0       2.0   2.0          NaN
# 12899     Private room             3        1.0       2.0   2.0          NaN
# 16688  Entire home/apt             8        2.0       2.0   3.0          NaN
# 25200     Private room             2        1.0       1.0   1.0          NaN
# 26203     Private room             2        1.0       1.0   1.0          NaN
#
#          price cleaning_fee  guests_included extra_people  minimum_nights  \
# id
# 7893   $175.00          NaN                1        $0.00               3
# 12899   $65.00       $20.00                2       $15.00               2
# 16688  $295.00       $95.00                6       $25.00               2
# 25200   $69.00       $30.00                1       $10.00               7
# 26203   $69.00       $30.00                1       $10.00              30
#
#        availability_365  reviews_per_month   latitude   longitude  bed_type
# id
# 7893                  0               0.02  45.575479 -122.666777  Real Bed
# 12899               294               4.64  45.564010 -122.634717  Real Bed
# 16688               333               1.92  45.525418 -122.685566    Airbed
# 25200               177               0.29  45.556750 -122.677839  Real Bed
# 26203                97               0.26  45.556965 -122.675656  Real Bed

# %%
# Clean numeric fields
num_feats = ['cleaning_fee', 'extra_people', 'price']
df[num_feats] = df[num_feats].replace('[\$,]', '', regex=True)
df[num_feats] = df[num_feats].apply(pd.to_numeric, errors='coerce')
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 4944 rows, 18 columns.

# %%
df.describe()
# Out:
#        accommodates    bathrooms    bedrooms         beds  square_feet  \
# count   4944.000000  4941.000000  4942.00000  4941.000000    93.000000
# mean       3.431230     1.232139     1.35431     1.855697   734.139785
# std        1.863576     0.517749     0.87750     1.189369   493.846143
# min        1.000000     0.000000     0.00000     1.000000     0.000000
# 25%        2.000000     1.000000     1.00000     1.000000   450.000000
# 50%        3.000000     1.000000     1.00000     1.000000   700.000000
# 75%        4.000000     1.000000     2.00000     2.000000   900.000000
# max       16.000000     6.000000     8.00000    16.000000  2500.000000
#
#              price  cleaning_fee  guests_included  extra_people  \
# count  4944.000000   4266.000000      4944.000000   4944.000000
# mean    120.056230     53.979606         1.810882     11.153519
# std     155.109419     43.746363         1.244382     16.375861
# min       0.000000      0.000000         1.000000      0.000000
# 25%      67.000000     25.000000         1.000000      0.000000
# 50%      95.000000     45.000000         1.000000      9.000000
# 75%     132.250000     75.000000         2.000000     20.000000
# max    8400.000000    359.000000        15.000000    300.000000
#
#        minimum_nights  availability_365  reviews_per_month     latitude  \
# count     4944.000000       4944.000000        4527.000000  4944.000000
# mean         3.119539        132.136327           2.909055    45.527811
# std          7.411169        123.413842           2.508788     0.033229
# min          1.000000          0.000000           0.010000    45.433945
# 25%          1.000000         15.750000           0.850000    45.505167
# 50%          2.000000         94.500000           2.320000    45.526648
# 75%          2.000000        254.000000           4.310000    45.555754
# max        222.000000        365.000000          22.930000    45.612011
#
#          longitude
# count  4944.000000
# mean   -122.647977
# std       0.045750
# min    -122.833981
# 25%    -122.680319
# 50%    -122.648781
# 75%    -122.621843
# max    -122.483763

# %% [markdown]
# ### Remove data which is not relevant for this model (part time listing and new)
# To compare apple to apple, remove part-time listings by removing availability <60 days a year, and also newly-listed listings with availability >300 days (using the other tail end as approximation).
#
# Before droping data looks like this

# %%
#Distribution of availability_365
# %matplotlib inline

fig, axs = plt.subplots(ncols=2, figsize=(24, 4))
fig.suptitle('Distribution of availability (before and after removing part-time listings)')

# Before cleaning
x_axis=df['availability_365'].dropna()
sns.distplot(pd.Series(x_axis, name='Availability (before cleaning)'), ax=axs[0])

# Remove where availability less than 60 days or greater than 300 days
df = df.query('60 <= availability_365 <= 300')
print("Dataset has {} rows, {} columns.".format(*df.shape))

#After cleaning
x_axis=df['availability_365'].dropna()
sns.distplot(pd.Series(x_axis, name='Availability (after cleaning)'), ax=axs[1])
df = df.drop('availability_365', axis = 1)
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 2092 rows, 18 columns.
# Dataset has 2092 rows, 17 columns.

# %% [markdown]
# ### Remove outliers places which can accomodate large number of people
# Remove outliers such as accomodating more than 10 people. We can tailor made solutions for such houses.

# %%
#Distribution of price
# %matplotlib inline

fig, axs = plt.subplots(ncols=2, figsize=(16, 4))
fig.suptitle('Distribution of max guests (before and after removing large listings > 10)', weight='bold', fontsize=12)

# Before cleaning
x_axis=df['accommodates'].dropna()
sns.distplot(pd.Series(x_axis, name='Max guests (before cleaning)'), ax=axs[0])

# Remove where price > 1000
condition = df[df['accommodates'] > 10]
rows_to_drop = condition.index
print("You dropped {} rows.".format(condition.shape[0]))
df = df.drop(rows_to_drop, axis=0)
print("Dataset has {} rows, {} columns.".format(*df.shape))

#After cleaning
x_axis=df['accommodates'].dropna()
sns.distplot(pd.Series(x_axis, name='Max guests (after cleaning)'), ax=axs[1])
# Out:
# You dropped 14 rows.
# Dataset has 2078 rows, 17 columns.

# %% [markdown]
# ### Remove high priced right-skewed data
#
# Removing more than $600

# %%
#Distribution of price
# %matplotlib inline

fig, axs = plt.subplots(ncols=2, figsize=(16, 4))
fig.suptitle('Distribution of price (before and after removing high-priced outliers)')

# Before cleaning
x_axis=df['price'].dropna()
sns.distplot(pd.Series(x_axis, name='Price (before cleaning)'), ax=axs[0])

# Remove where price > 1000
condition = df[df['price'] > 600]
rows_to_drop = condition.index
print("You dropped {} rows.".format(condition.shape[0]))
df = df.drop(rows_to_drop, axis=0)
print("Dataset has {} rows, {} columns.".format(*df.shape))

#After cleaning
x_axis=df['price'].dropna()
sns.distplot(pd.Series(x_axis, name='Price  (after cleaning)'), ax=axs[1])
# Out:
# You dropped 4 rows.
# Dataset has 2073 rows, 17 columns.

# %% [markdown]
# ### merging rare property types into others
# For certain categories we dont have enough data, so we will merge them into one

# %%
df['property_type'].value_counts()
# Out:
# House                 823
# Apartment             446
# Guest suite           271
# Guesthouse            199
# Bungalow               80
# Condominium            48
# Townhouse              44
# Boutique hotel         33
# Loft                   29
# Bed and breakfast      22
# Tiny house             21
# Camper/RV              13
# Cottage                 9
# Hostel                  6
# Other                   6
# Boat                    4
# Cabin                   4
# Tent                    4
# Villa                   3
# Serviced apartment      2
# Bus                     1
# Hut                     1
# Farm stay               1
# Yurt                    1
# Houseboat               1
# Earth house             1
# Name: property_type, dtype: int64

# %% [markdown]
# Will use only House, Apartment, Guest Suites, Guesthouse

# %%
categories_to_rename = ['Bungalow','Condominium','Townhouse','Boutique hotel','Loft','Bed and breakfast', 'Tiny house', 
                        'Camper/RV','Cottage', 'Hostel', 'Boat','Cabin','Tent','Serviced apartment','Villa','Bus','Hut', 'Farm stay', 'Yurt','Houseboat', 'Earth house']
df['property_type'].loc[df['property_type'].isin(categories_to_rename)] = 'Other'
# Out:
# /home/dheeraj/work/env1/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['property_type'].value_counts()
# Out:
# House          823
# Apartment      446
# Other          334
# Guest suite    271
# Guesthouse     199
# Name: property_type, dtype: int64

# %% [markdown]
# ### Yield Calculation
#
# Yield is defined as the amount of revenue that a property will earn over a year.
#
# Yield = AVERAGE LENGTH OF STAY X PRICE X NO. OF REVIEWS/MTH X REVIEW RATE X 12 MONTHS
#
# Assume, an average length of stay in Portland is 3 nights with a review rate of 50%. Note that this is fairly conservative, and yield in reality is likely to be higher.
#
# Check out the distribution of price and reviews per month

# %%
#Distribution of yield, availability_365, reviews_per_month
# %matplotlib inline

fig, axs = plt.subplots(ncols=2, figsize=(16, 4))
fig.suptitle('Distribution of variables for calculation of yield')
x_axis=df['price'].dropna()
sns.distplot(pd.Series(x_axis, name=x_axis.name), ax=axs[0])
x_axis=df['reviews_per_month'].dropna()
sns.distplot(pd.Series(x_axis, name=x_axis.name), ax=axs[1])

# %% [markdown]
# Average price is $120, average reviews received are 3

# %%
# Calculate yield

# Average length of stay (by city) X Price ('price') X No. of reviews('reviews_per_month') / Review rate('50%')
avg_length_of_stay_portland = 3
review_rate = 0.5
df['price'] = df['price'] + df['cleaning_fee']
df['yield'] = avg_length_of_stay_portland * df['price'] * (df['reviews_per_month'] / review_rate) * 12

cols_to_drop = ['cleaning_fee']
df = df.drop(cols_to_drop, axis = 1)
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 2073 rows, 17 columns.

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(15,6))
fig.suptitle('Distribution of Yield ')
x_axes = df['yield'].dropna()
x = pd.Series(x_axis, name=x_axis.name)
ax = sns.distplot(x)

# %%
df['yield'].describe()
# Out:
# count      1787.000000
# mean      37454.473330
# std       31670.123061
# min          99.360000
# 25%       13521.600000
# 50%       29640.960000
# 75%       53500.320000
# max      307540.800000
# Name: yield, dtype: float64

# %%
df.describe()
# Out:
#        accommodates    bathrooms     bedrooms         beds  square_feet  \
# count   2073.000000  2072.000000  2071.000000  2072.000000    46.000000
# mean       3.328509     1.207529     1.265572     1.817568   723.195652
# std        1.676732     0.508148     0.797319     1.084334   309.577463
# min        1.000000     0.000000     0.000000     1.000000   120.000000
# 25%        2.000000     1.000000     1.000000     1.000000   500.000000
# 50%        3.000000     1.000000     1.000000     2.000000   782.000000
# 75%        4.000000     1.000000     2.000000     2.000000   800.000000
# max       10.000000     6.000000     5.000000     9.000000  1800.000000
#
#              price  guests_included  extra_people  minimum_nights  \
# count  1860.000000      2073.000000   2073.000000     2073.000000
# mean    166.368280         1.859624     12.606368        3.373854
# std     104.801004         1.205311     19.115237        8.207118
# min      29.000000         1.000000      0.000000        1.000000
# 25%      99.000000         1.000000      0.000000        1.000000
# 50%     140.000000         2.000000     10.000000        2.000000
# 75%     200.000000         2.000000     20.000000        2.000000
# max     800.000000        12.000000    300.000000      222.000000
#
#        reviews_per_month     latitude    longitude          yield
# count        1969.000000  2073.000000  2073.000000    1787.000000
# mean            3.560188    45.528354  -122.649107   37454.473330
# std             2.610554     0.032952     0.044849   31670.123061
# min             0.020000    45.435280  -122.833981      99.360000
# 25%             1.430000    45.506039  -122.680640   13521.600000
# 50%             3.100000    45.526815  -122.648993   29640.960000
# 75%             5.150000    45.556401  -122.623180   53500.320000
# max            13.870000    45.606626  -122.491622  307540.800000

# %% [markdown]
# square_feet is available only for 46 listing.
# There are over 200 places where price is missing, reviews per month missing for over 100 places.
#
# Will drop these in our calculation

# %%
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %%
# Remove missing yield values
df = df.dropna(subset=['yield'])

# Remove square_feet as it is too sparse.
df = df.drop('square_feet', axis=1)

# %%
from sklearn.preprocessing import Imputer
# Impute most frequent for categorical features
categorical_feats = df.select_dtypes(include=['object']).columns
df[categorical_feats] = DataFrameImputer().fit_transform(df[categorical_feats])

# Impute median for numerical features
num_feats = df.select_dtypes(include=[np.number]).columns
imp = Imputer(missing_values=np.nan, strategy='median', axis=0)
df[num_feats] = imp.fit_transform(df[num_feats])

print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 1787 rows, 16 columns.

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Topic modelling (Description)
#
# We are going to use Natural Language Processing pipeline to convert the corpus into a Document-Term-Matrix, whereby each listing (document) consists of a matrix of terms (processed words).
#
# Once that is done we will use Latent Dirichlet Allocation (LDA) to discover topics inherent in the corpus, classify the corpus according to the learned topics and use them as features for the regression model.
#
# LDA is a generative Bayesian inference model that associates each document with a probability distribution over topics, where topics are probability distributions over words. It is an efficient way to analyse large volumes of text and is a more human interpretable method of topic modelling.

# %%
# Seperate NLP features
nlp_feats = ['description']
corpus = df[nlp_feats]
df = df.drop(nlp_feats, axis = 1)
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 1787 rows, 15 columns.

# %%
import nltk
nltk.data.path.append("./nltk_data")

from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from gensim.corpora.dictionary import Dictionary
from gensim.models.tfidfmodel import TfidfModel
from gensim.models.ldamodel import LdaModel

import itertools
from collections import Counter
from collections import defaultdict

import json
import pyLDAvis.gensim
pyLDAvis.enable_notebook()

# %%
def preprocess_text(corpus):
    """Takes a corpus in list format and applies basic preprocessing steps of word tokenization,
     removing of english stop words, lower case and lemmatization."""
    processed_corpus = []
    english_words = set(nltk.corpus.words.words())
    english_stopwords = set(stopwords.words('english'))
    wordnet_lemmatizer = WordNetLemmatizer()
    tokenizer = RegexpTokenizer(r'[\w|!]+')
    for row in corpus:
        word_tokens = tokenizer.tokenize(row)
        word_tokens_lower = [t.lower() for t in word_tokens]
        word_tokens_lower_english = [t for t in word_tokens_lower if t in english_words or not t.isalpha()]
        word_tokens_no_stops = [t for t in word_tokens_lower_english if not t in english_stopwords]
        word_tokens_no_stops_lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in word_tokens_no_stops]
        processed_corpus.append(word_tokens_no_stops_lemmatized)
    return processed_corpus

# %%
def nlp_model_pipeline(processed_corpus):
    """Takes processed corpus and produce dictionary, doc_term_matrix and LDA model"""
    # Creates the term dictionary (every unique term in corpus is assigned an index)
    dictionary = Dictionary(processed_corpus)
    # Convert corpus into Document Term Matrix using dictionary prepared above
    doc_term_matrix = [dictionary.doc2bow(listing) for listing in processed_corpus]    
    return dictionary, doc_term_matrix

# %%
def LDA_topic_modelling(doc_term_matrix, dictionary, num_topics=3, passes=2):
    # Create an object for LDA model and train it on Document-Term-Matrix
    LDA = LdaModel
    ldamodel = LDA(doc_term_matrix, num_topics=num_topics, id2word = dictionary, passes=passes)
    return ldamodel

# %%
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

def add_topics_to_df(ldamodel, doc_term_matrix, df, new_col, num_topics):
    # Convert into Per-document topic probability matrix:
    docTopicProbMat = ldamodel[doc_term_matrix]
       
    docTopicProbDf = pd.DataFrame(index=df.index, columns=range(0, num_topics))
    
    docTopicProbDf.dtypes.eq(object) # you can see the type of best_c
    new = docTopicProbDf.columns[docTopicProbDf.dtypes.eq(object)] #get the object column of the best_c
    docTopicProbDf[new] = docTopicProbDf[new].apply(pd.to_numeric, errors = 'coerce', axis=0) # change the type of object
    
    for i, doc in enumerate(docTopicProbMat):
        for topic in doc:
            docTopicProbDf.iloc[i, topic[0]] = topic[1]
    
    
    docTopicProbDf[new_col] = docTopicProbDf.idxmax(axis=1)
    df_topics = docTopicProbDf[new_col]
    # Merge with df
    df_new = pd.concat([df, df_topics], axis=1)
    return df_new

# %%
corpus.head()
# Out:
#                                              description
# id
# 12899  Settle in to a space of your own. You'll have ...
# 25200  If you are an Urban Farming pioneer, enthusias...
# 26203  If you are an Urban Farming pioneer, enthusias...
# 29931  This house is wonderfully located near downtow...
# 59425  Our apartment feels just like home. We created...

# %%
# %%time
corpus_description = corpus['description'].astype(str)
processed_corpus_description = preprocess_text(corpus_description)
dictionary_description, doc_term_matrix_description = nlp_model_pipeline(processed_corpus_description)
# Out:
# CPU times: user 943 ms, sys: 6.31 ms, total: 949 ms
# Wall time: 947 ms

# %%
# %%time
ldamodel_description = LDA_topic_modelling(doc_term_matrix_description, dictionary_description, num_topics=3, passes=1)
# Out:
# CPU times: user 2.12 s, sys: 0 ns, total: 2.12 s
# Wall time: 2.12 s

# %% [markdown]
# Creating visualizations that summarizes or extracts a relevant characteristic or feature about the data.

# %%
# %%time
pyLDAvis.gensim.prepare(ldamodel_description, doc_term_matrix_description, dictionary_description)
# Out:
# CPU times: user 995 ms, sys: 0 ns, total: 995 ms
# Wall time: 1.11 s
# /home/dheeraj/work/env1/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.001699 -0.009317       1        1  42.585773
# 2     -0.009103  0.005851       2        1  32.079998
# 0      0.010802  0.003465       3        1  25.334230, topic_info=     Category         Freq            Term        Total  loglift  logprob
# term
# 217   Default   801.000000          street   801.000000  30.0000  30.0000
# 2     Default   884.000000          access   884.000000  29.0000  29.0000
# 153   Default   670.000000             new   670.000000  28.0000  28.0000
# 6     Default  1037.000000       apartment  1037.000000  27.0000  27.0000
# 137   Default   868.000000          coffee   868.000000  26.0000  26.0000
# 169   Default   820.000000            walk   820.000000  25.0000  25.0000
# 192   Default   453.000000            easy   453.000000  24.0000  24.0000
# 13    Default  1235.000000             bed  1235.000000  23.0000  23.0000
# 36    Default   973.000000    neighborhood   973.000000  22.0000  22.0000
# 21    Default   630.000000           enjoy   630.000000  21.0000  21.0000
# 98    Default   651.000000           large   651.000000  20.0000  20.0000
# 7     Default   678.000000            area   678.000000  19.0000  19.0000
# 134   Default   565.000000            away   565.000000  18.0000  18.0000
# 1     Default   742.000000               2   742.000000  17.0000  17.0000
# 136   Default  1207.000000         bedroom  1207.000000  16.0000  16.0000
# 148   Default   889.000000          living   889.000000  15.0000  15.0000
# 243   Default   473.000000            need   473.000000  14.0000  14.0000
# 51    Default   377.000000           small   377.000000  13.0000  13.0000
# 20    Default   908.000000        downtown   908.000000  12.0000  12.0000
# 37    Default   891.000000             one   891.000000  11.0000  11.0000
# 15    Default   526.000000            city   526.000000  10.0000  10.0000
# 687   Default   418.000000           guest   418.000000   9.0000   9.0000
# 29    Default  1309.000000         kitchen  1309.000000   8.0000   8.0000
# 200   Default  1620.000000            home  1620.000000   7.0000   7.0000
# 197   Default   986.000000            full   986.000000   6.0000   6.0000
# 296   Default   449.000000           place   449.000000   5.0000   5.0000
# 514   Default   274.000000           built   274.000000   4.0000   4.0000
# 303   Default   173.000000  transportation   173.000000   3.0000   3.0000
# 295   Default   454.000000         parking   454.000000   2.0000   2.0000
# 500   Default   299.000000            many   299.000000   1.0000   1.0000
# ...       ...          ...             ...          ...      ...      ...
# 317    Topic3    88.124138            high   252.073944   0.3220  -5.9963
# 296    Topic3   144.141251           place   449.560486   0.2355  -5.5043
# 21     Topic3   191.263062           enjoy   630.321289   0.1804  -5.2214
# 136    Topic3   334.143707         bedroom  1207.197998   0.0885  -4.6635
# 148    Topic3   255.896317          living   889.329163   0.1273  -4.9303
# 29     Topic3   344.669586         kitchen  1309.821045   0.0380  -4.6325
# 45     Topic3    55.409058             see   149.506409   0.3804  -6.4603
# 422    Topic3   176.077850           floor   596.912964   0.1522  -5.3041
# 497    Topic3   104.975761           heart   326.248077   0.2391  -5.8213
# 295    Topic3   137.906815         parking   454.627197   0.1801  -5.5485
# 59     Topic3   121.034370          within   392.137085   0.1975  -5.6790
# 147    Topic3   347.909363           house  1460.280029  -0.0614  -4.6231
# 14     Topic3   133.295670             bus   447.848267   0.1611  -5.5825
# 40     Topic3   347.300598         private  1632.916504  -0.1749  -4.6249
# 243    Topic3   137.105759            need   473.333374   0.1340  -5.5543
# 1      Topic3   190.595947               2   742.144287   0.0136  -5.2249
# 200    Topic3   335.838104            home  1620.083130  -0.2006  -4.6584
# 13     Topic3   273.287689             bed  1235.365845  -0.1356  -4.8645
# 197    Topic3   227.158600            full   986.622437  -0.0956  -5.0494
# 169    Topic3   199.977600            walk   820.681946  -0.0389  -5.1768
# 20     Topic3   213.638885        downtown   908.056274  -0.0740  -5.1108
# 161    Topic3   336.727234            room  1802.013184  -0.3044  -4.6558
# 134    Topic3   154.552505            away   565.583740   0.0757  -5.4345
# 16     Topic3   166.822540           close   642.377686   0.0248  -5.3581
# 26     Topic3   175.084183           great   695.753967  -0.0067  -5.3098
# 37     Topic3   191.938904             one   891.971497  -0.1632  -5.2179
# 52     Topic3   208.606857           space  1198.717163  -0.3755  -5.1346
# 254    Topic3   146.816116            stay   555.724487   0.0419  -5.4859
# 41     Topic3   157.771118           queen   874.742554  -0.3398  -5.4139
# 54     Topic3   154.947098             two   797.050964  -0.2648  -5.4320
#
# [286 rows x 6 columns], token_table=      Topic      Freq           Term
# term
# 445       1  0.405830              1
# 445       2  0.357716              1
# 445       3  0.236385              1
# 1386      2  0.712414          1080i
# 1386      3  0.356207          1080i
# 0         1  0.559671             15
# 0         2  0.277220             15
# 0         3  0.162148             15
# 4703      1  0.354261           1899
# 4703      3  0.708522           1899
# 5248      3  0.534611          1900!
# 1         1  0.355726              2
# 1         2  0.388065              2
# 1         3  0.257362              2
# 4195      1  0.677619          240sf
# 4195      2  0.338810          240sf
# 1511      1  0.760277           28th
# 1511      2  0.126713           28th
# 1511      3  0.126713           28th
# 2         1  0.381956         access
# 2         2  0.271212         access
# 2         3  0.346925         access
# 5225      1  0.264759         adult!
# 5225      2  0.529517         adult!
# 5838      2  0.357045            ale
# 5838      3  0.714090            ale
# 4         1  0.393392           also
# 4         2  0.400677           also
# 4         3  0.207624           also
# 5458      2  0.533918       amenable
# ...     ...       ...            ...
# 396       3  0.205440            use
# 1404      2  0.713234          villa
# 1404      3  0.356617          villa
# 5722      1  0.214208         villa!
# 5722      2  0.642624         villa!
# 5722      3  0.214208         villa!
# 169       1  0.325339           walk
# 169       2  0.431349           walk
# 169       3  0.243700           walk
# 56        1  0.464561        walking
# 56        2  0.275093        walking
# 56        3  0.260518        walking
# 944       1  0.290755          water
# 944       2  0.519835          water
# 944       3  0.185026          water
# 5224      1  0.294218          wired
# 5224      2  0.647280          wired
# 5224      3  0.058844          wired
# 3677      2  0.533744         wiring
# 59        1  0.359568         within
# 59        2  0.331517         within
# 59        3  0.308566         within
# 1452      1  0.761857           wrap
# 1452      2  0.126976           wrap
# 1452      3  0.126976           wrap
# 397       1  0.572323           yard
# 397       2  0.223511           yard
# 397       3  0.206578           yard
# 5912      2  0.533526          出门3分钟
# 5913      2  0.533412  后面的院子有16000多坪
#
# [516 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 3, 1])

# %% [markdown]
# topic 1 relates more to room, private, apartment
# topic 2 relates more to home
# topic 3 relates more to  house, access, street

# %% [markdown]
# ### Algorithms and Techniques
#
# I intend to use 3 regression algorithms:
#
# 1. Linear Regression
#
# To establish a baseline model
#
# 2. Decision Tree
#
# This is a more complex model that can capture nonlinear relationships in the dataset whilst still retaining interpretability. This is also robust to missing values, and has the added advantage of being able to help with feature selection based on feature importance.
#
# 3. Random Forest
#
# This is the most complex ensemble model built from decision trees, and should be able to provide additional accuracy. While it sacrifices interpretability, sense checking can be made with the earlier decision tree model whilst added an interpretation layer using Tree Interpreter allows model users to break down individual predictions.

# %% [markdown]
# # Methodology

# %% [markdown]
# ### Data Preprocessing
#
# Correcting abnormalities or certain characteristics.
#
# Before performing any machine learning, the dataset needs to be pre-processed.
#
# The following steps were taken for this project and discussed in the 'Data Exploration' section of the report:
#     Converting data types (e.g. string into integers)
#     Removing part-time listings
#     Removing large houses
#     Removing high-priced rentals
#     Changing minor category times into ‘Other’
#     Calculation of yield
#     Topic modelling
#
# In addition to those steps already taken, missing values need to be imputed, features have to be selected and categorical features have to be encoded.

# %%
df.describe()
# Out:
#        accommodates    bathrooms     bedrooms         beds        price  \
# count   1787.000000  1787.000000  1787.000000  1787.000000  1787.000000
# mean       3.420817     1.175434     1.278120     1.860101   163.711248
# std        1.665059     0.438714     0.802702     1.085129   102.894604
# min        1.000000     0.000000     0.000000     1.000000    29.000000
# 25%        2.000000     1.000000     1.000000     1.000000    99.000000
# 50%        3.000000     1.000000     1.000000     2.000000   138.000000
# 75%        4.000000     1.000000     2.000000     2.000000   195.000000
# max       10.000000     4.500000     5.000000     9.000000   800.000000
#
#        guests_included  extra_people  minimum_nights  reviews_per_month  \
# count      1787.000000   1787.000000     1787.000000        1787.000000
# mean          1.924454     13.367655        3.477896           3.575797
# std           1.225613     19.812580        8.647439           2.603428
# min           1.000000      0.000000        1.000000           0.020000
# 25%           1.000000      0.000000        1.000000           1.450000
# 50%           2.000000     10.000000        2.000000           3.130000
# 75%           2.000000     20.000000        2.000000           5.170000
# max          12.000000    300.000000      222.000000          13.870000
#
#           latitude    longitude          yield
# count  1787.000000  1787.000000    1787.000000
# mean     45.528792  -122.648976   37454.473330
# std       0.032975     0.044494   31670.123061
# min      45.435280  -122.833981      99.360000
# 25%      45.506613  -122.681300   13521.600000
# 50%      45.527827  -122.648473   29640.960000
# 75%      45.556812  -122.622745   53500.320000
# max      45.606019  -122.493942  307540.800000

# %% [markdown]
# ### Feature selection
#
# Remove features that are not necessary for the machine learning phase.
#
# 'Price' and 'reviews_per_month' are removed as they are used to calculate 'yield' and would have a strong correlation with 'yield'.

# %%
cols_to_drop = ['price', 'reviews_per_month']
df_final_viz = df[cols_to_drop]
df = df.drop(cols_to_drop, axis = 1)
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 1787 rows, 13 columns.

# %% [markdown]
# ### Dummy encoding
#
# categorical features need to be encoded to be treated properly by the machine learning algorithms. As the algorithms require numerical features only, the different categories have to be given a number. However, the categorical features present do not have any order inherent in them (eg. apartment vs. house) and thus needs to be encoded where 1 is given if the category is true and 0 is not.

# %%
# Dummy encoding
categorical_feats = ['property_type', 'room_type', 'bed_type']
df = pd.get_dummies(df, columns=categorical_feats, drop_first=False)
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 1787 rows, 23 columns.

# %%
df.head()
# Out:
#        accommodates  bathrooms  bedrooms  beds  guests_included  extra_people  \
# id
# 12899           3.0        1.0       2.0   2.0              2.0          15.0
# 25200           2.0        1.0       1.0   1.0              1.0          10.0
# 26203           2.0        1.0       1.0   1.0              1.0          10.0
# 29931           6.0        2.0       3.0   3.0              4.0          50.0
# 59425           4.0        1.0       1.0   2.0              2.0          10.0
#
#        minimum_nights   latitude   longitude     yield        ...          \
# id                                                            ...
# 12899             2.0  45.564010 -122.634717  28396.80        ...
# 25200             7.0  45.556750 -122.677839   2067.12        ...
# 26203            30.0  45.556965 -122.675656   1853.28        ...
# 29931             2.0  45.482782 -122.720891  13104.00        ...
# 59425             2.0  45.561805 -122.650969   1778.40        ...
#
#        property_type_House  property_type_Other  room_type_Entire home/apt  \
# id
# 12899                    0                    0                          0
# 25200                    1                    0                          0
# 26203                    1                    0                          0
# 29931                    1                    0                          1
# 59425                    0                    0                          1
#
#        room_type_Private room  room_type_Shared room  bed_type_Airbed  \
# id
# 12899                       1                      0                0
# 25200                       1                      0                0
# 26203                       1                      0                0
# 29931                       0                      0                0
# 59425                       0                      0                0
#
#        bed_type_Couch  bed_type_Futon  bed_type_Pull-out Sofa  \
# id
# 12899               0               0                       0
# 25200               0               0                       0
# 26203               0               0                       0
# 29931               0               0                       0
# 59425               0               0                       0
#
#        bed_type_Real Bed
# id
# 12899                  1
# 25200                  1
# 26203                  1
# 29931                  1
# 59425                  1
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Implementation
#
# As a first step, the target variable 'yield' has to be seperated from the response variables to from the X and y data sets.

# %%
# Create response and target variable
target = 'yield'
X = df.drop(target, axis=1)
y = df[target]

# %% [markdown]
# Step 2 - Both X and y data sets and respectively split into a training set and a testing set. I chose to use 30% of the data set for the testing set. As part of the splitting process, the data set is also shuffled to ensure there is no inherent or hidden order to the data set and that both the testing and training sets are a fair representative of the complete data set.

# %%
# Train test split
from sklearn.model_selection import train_test_split
test_size = 0.3
seed = 42

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# %% [markdown]
# In the training phase, the training set is fitted to the 3 algorithms.
#
# During this process, the models are tuned using scikit-learn's GridSearchCV function. This allows us to set out a grid of parameters to iteratively train and set the models on and ultimately choose the best parameters.
#
# As tree-based algorithms are being applied, the parameters being tuned are the max no. of features used, the max depth of trees, the minimum sample split and the no. of trees grown (for random forest).
#
# ### Linear regression model

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the testing set
regr_y_pred = regr.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, regr_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, regr_y_pred))
# Out:
# Mean squared error: 734891569.78
# Variance score: 0.12

# %% [markdown]
# ### Decision tree model

# %%
from sklearn.tree import DecisionTreeRegressor
# Fit regression model
dt_regr = DecisionTreeRegressor(random_state=seed, max_depth=5)
dt_regr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='best')

# %%
# Make prediction
dt_y_pred = dt_regr.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, dt_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, dt_y_pred))
# Out:
# Mean squared error: 756835346.64
# Variance score: 0.09

# %% [markdown]
# ### Random forest model

# %%
from sklearn.ensemble import RandomForestRegressor
# Out:
# /home/dheeraj/work/env1/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# %%time
rf_regr = RandomForestRegressor(random_state=seed, bootstrap=True, criterion='mse', max_depth=10, 
                           max_features='auto', min_samples_split=4, n_estimators=150)
rf_regr.fit(X_train, y_train)
# Out:
# CPU times: user 403 ms, sys: 0 ns, total: 403 ms
# Wall time: 402 ms

# %%
# Make prediction
rf_y_pred = rf_regr.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, rf_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, rf_y_pred))
# Out:
# Mean squared error: 560914903.61
# Variance score: 0.33

# %% [markdown]
# ### Refinement
#
# Refinement process includes adjusting of parameters for certain models to acquire improved solutions.
#
# In the 'Problem Statement' section, it was first highlighted that one of the key aspects of this project is to test the predictive value of textual information in AirBnb listings. As such, one of they key refinements made is to include the earlier topics that have been modelled using LDA (explained in the 'Data Exploration' section). Each listing is classified into one topic based on probability determined by the trained LDA model. This topic is then added in as a few feature.

# %%
df = add_topics_to_df(ldamodel_description, doc_term_matrix_description, df, new_col='topics_description', num_topics=3)

# Rename based on understanding of topics
df['topics_description'].replace({0:'Luxury', 1:'Business', 2:'Budget'},inplace=True)
df = pd.get_dummies(df, columns=['topics_description'], drop_first=False)

print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 1787 rows, 26 columns.

# %%
# Create response and target variable
X = df.drop(target, axis=1)
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# %%
# %%time
rf_regr.fit(X_train, y_train)
# Out:
# CPU times: user 426 ms, sys: 76 µs, total: 426 ms
# Wall time: 426 ms
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=4,
#            min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
# Make prediction
rf_y_pred = rf_regr.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, rf_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, rf_y_pred))
# Out:
# Mean squared error: 560567673.32
# Variance score: 0.33

# %% [markdown]
# Without desc
#
# Mean squared error: 560914903.61
# Variance score: 0.33
#
# With Desc
# Mean squared error: 560567673.32
# Variance score: 0.33

# %% [markdown]
# ### Tuning the final model
# After confirming that including NLP features helps to improve accuracy, it is included in the final model. The parameters for the final Random Forest model is then tuned using scikit-learn's GridSearchCV.
#
# A parameters grid of hyperparameters are created for GridSearchCV to iteratively use and test for the best cross-validated accuracy. The paramters being tuned are: Number of estimators, the maximum depth and the minimum samples split. After tuning, the best parameters are a max_depth of 15, minimum samples split of 10 and number of estimators 200

# %%
#Tuning the model
param_grid = { "n_estimators"      : [175, 200, 225, 250],
           "criterion"         : ['mse'],
           "max_features"      : ['auto'], #auto, sqrt, log2, int/n_feature
           "max_depth"         : [10, 14, 15, 16, 18],
           "min_samples_split" : [6, 7, 8, 9, 10] ,
           "bootstrap": [True]}

# %%
# %%time
rf = RandomForestRegressor(random_state=seed)

rf_cv = GridSearchCV(rf, param_grid, cv=5)
rf_cv.fit(X_train, y_train)
# Out:
# CPU times: user 4min 40s, sys: 20.8 ms, total: 4min 40s
# Wall time: 4min 40s

# %%
# Make prediction
rf_y_pred = rf_cv.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, rf_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, rf_y_pred))
# Best params
print("Tuned Model Parameters: {}".format(rf_cv.best_params_))
# Out:
# Mean squared error: 556048489.53
# Variance score: 0.33
# Tuned Model Parameters: {'bootstrap': True, 'criterion': 'mse', 'max_depth': 16, 'max_features': 'auto', 'min_samples_split': 10, 'n_estimators': 225}

# %% [markdown]
# ## Model Evaluation and Validation

# %%
# Change variables
random_state = 59

X = df.drop(target, axis=1)
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# Fit and make prediction
rf_regr.fit(X_train, y_train)
rf_y_pred = rf_regr.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, rf_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, rf_y_pred))
# Out:
# Mean squared error: 560567673.32
# Variance score: 0.33

# %%
# Change variables
test_size = 0.2

X = df.drop(target, axis=1)
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# Fit and make prediction
rf_regr.fit(X_train, y_train)
rf_y_pred = rf_regr.predict(X_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, rf_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, rf_y_pred))
# Out:
# Mean squared error: 529977398.24
# Variance score: 0.37

# %%
X_test.head()
# Out:
#           accommodates  bathrooms  bedrooms  beds  guests_included  \
# id
# 8985260            4.0        1.0       1.0   2.0              2.0
# 19012175           6.0        2.0       2.0   3.0              1.0
# 20709084           4.0        1.0       1.0   2.0              3.0
# 4378910            2.0        1.0       1.0   1.0              1.0
# 25935157           9.0        2.0       4.0   6.0              1.0
#
#           extra_people  minimum_nights   latitude   longitude  \
# id
# 8985260           25.0             2.0  45.507665 -122.609853
# 19012175           0.0             1.0  45.531931 -122.682019
# 20709084          10.0             1.0  45.535811 -122.567628
# 4378910           10.0             1.0  45.492141 -122.681425
# 25935157           0.0             2.0  45.530574 -122.699201
#
#           property_type_Apartment            ...              \
# id                                           ...
# 8985260                         0            ...
# 19012175                        1            ...
# 20709084                        0            ...
# 4378910                         0            ...
# 25935157                        0            ...
#
#           room_type_Private room  room_type_Shared room  bed_type_Airbed  \
# id
# 8985260                        0                      0                0
# 19012175                       0                      0                0
# 20709084                       0                      0                0
# 4378910                        1                      0                0
# 25935157                       0                      0                0
#
#           bed_type_Couch  bed_type_Futon  bed_type_Pull-out Sofa  \
# id
# 8985260                0               0                       0
# 19012175               0               0                       0
# 20709084               0               0                       0
# 4378910                0               0                       0
# 25935157               0               0                       0
#
#           bed_type_Real Bed  topics_description_Budget  \
# id
# 8985260                   1                          1
# 19012175                  1                          1
# 20709084                  1                          0
# 4378910                   1                          1
# 25935157                  1                          0
#
#           topics_description_Business  topics_description_Luxury
# id
# 8985260                             0                          0
# 19012175                            0                          0
# 20709084                            0                          1
# 4378910                             0                          0
# 25935157                            0                          1
#
# [5 rows x 25 columns]

# %%
X_test.loc[4378910]
# Out:
# accommodates                     2.000000
# bathrooms                        1.000000
# bedrooms                         1.000000
# beds                             1.000000
# guests_included                  1.000000
# extra_people                    10.000000
# minimum_nights                   1.000000
# latitude                        45.492141
# longitude                     -122.681425
# property_type_Apartment          0.000000
# property_type_Guest suite        0.000000
# property_type_Guesthouse         0.000000
# property_type_House              1.000000
# property_type_Other              0.000000
# room_type_Entire home/apt        0.000000
# room_type_Private room           1.000000
# room_type_Shared room            0.000000
# bed_type_Airbed                  0.000000
# bed_type_Couch                   0.000000
# bed_type_Futon                   0.000000
# bed_type_Pull-out Sofa           0.000000
# bed_type_Real Bed                1.000000
# topics_description_Budget        1.000000
# topics_description_Business      0.000000
# topics_description_Luxury        0.000000
# Name: 4378910, dtype: float64

# %%
test_data = X_test.loc[4378910]
print(rf_cv.predict(test_data.values.reshape(1, -1)))
# Out:
# [14257.06849167]

# %%
test_data['accommodates'] = 4
print(rf_cv.predict(test_data.values.reshape(1, -1)))

test_data['accommodates'] = 6
print(rf_cv.predict(test_data.values.reshape(1, -1)))
# Out:
# [18444.39790025]
# [19326.50108057]
# /home/dheeraj/work/env1/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/dheeraj/work/env1/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#Display feature importance
def feature_importance(model, trainData, display_n_rows):
    """Display feature importance & weighting for tree based model"""
    fi = model.feature_importances_*100
    feat_imp = pd.DataFrame(list(zip(fi,trainData.columns.values)))
    feat_imp = feat_imp.sort_values(by=0, axis=0, ascending=False)
    feat_imp.columns = ['importance %', 'feature']
    print(feat_imp[:display_n_rows])

# %%
#Display features & weighting
rf_best = rf_cv.best_estimator_
feature_importance(rf_best, X_train, 20)
# Out:
#     importance %                      feature
# 14     19.964849    room_type_Entire home/apt
# 7      17.945248                     latitude
# 6      17.032441               minimum_nights
# 8      12.123243                    longitude
# 0       8.439836                 accommodates
# 5       4.628247                 extra_people
# 3       4.520152                         beds
# 2       3.249358                     bedrooms
# 4       2.955471              guests_included
# 1       1.938276                    bathrooms
# 11      1.820797     property_type_Guesthouse
# 9       0.989137      property_type_Apartment
# 24      0.984398    topics_description_Luxury
# 12      0.829971          property_type_House
# 13      0.767547          property_type_Other
# 22      0.608869    topics_description_Budget
# 10      0.571564    property_type_Guest suite
# 23      0.559650  topics_description_Business
# 19      0.022788               bed_type_Futon
# 21      0.022657            bed_type_Real Bed

# %% [markdown]
# ### Visualization

# %%
df2 = df.join(df_final_viz)
nlp_feats = ['topics_description_Budget', 'topics_description_Business', 'topics_description_Luxury']
df2['topics_description'] = df2[nlp_feats].idxmax(axis=1)
df2['topics_description'] = df2['topics_description'].str.replace('topics_description_', '')

# %%
df.head()
# Out:
#        accommodates  bathrooms  bedrooms  beds  guests_included  extra_people  \
# id
# 12899           3.0        1.0       2.0   2.0              2.0          15.0
# 25200           2.0        1.0       1.0   1.0              1.0          10.0
# 26203           2.0        1.0       1.0   1.0              1.0          10.0
# 29931           6.0        2.0       3.0   3.0              4.0          50.0
# 59425           4.0        1.0       1.0   2.0              2.0          10.0
#
#        minimum_nights   latitude   longitude     yield  \
# id
# 12899             2.0  45.564010 -122.634717  28396.80
# 25200             7.0  45.556750 -122.677839   2067.12
# 26203            30.0  45.556965 -122.675656   1853.28
# 29931             2.0  45.482782 -122.720891  13104.00
# 59425             2.0  45.561805 -122.650969   1778.40
#
#                  ...              room_type_Private room  \
# id               ...
# 12899            ...                                   1
# 25200            ...                                   1
# 26203            ...                                   1
# 29931            ...                                   0
# 59425            ...                                   0
#
#        room_type_Shared room  bed_type_Airbed  bed_type_Couch  bed_type_Futon  \
# id
# 12899                      0                0               0               0
# 25200                      0                0               0               0
# 26203                      0                0               0               0
# 29931                      0                0               0               0
# 59425                      0                0               0               0
#
#        bed_type_Pull-out Sofa  bed_type_Real Bed  topics_description_Budget  \
# id
# 12899                       0                  1                          0
# 25200                       0                  1                          0
# 26203                       0                  1                          0
# 29931                       0                  1                          1
# 59425                       0                  1                          0
#
#        topics_description_Business  topics_description_Luxury
# id
# 12899                            1                          0
# 25200                            1                          0
# 26203                            1                          0
# 29931                            0                          0
# 59425                            0                          1
#
# [5 rows x 26 columns]

# %%
df2.head()
# Out:
#        accommodates  bathrooms  bedrooms  beds  guests_included  extra_people  \
# id
# 12899           3.0        1.0       2.0   2.0              2.0          15.0
# 25200           2.0        1.0       1.0   1.0              1.0          10.0
# 26203           2.0        1.0       1.0   1.0              1.0          10.0
# 29931           6.0        2.0       3.0   3.0              4.0          50.0
# 59425           4.0        1.0       1.0   2.0              2.0          10.0
#
#        minimum_nights   latitude   longitude     yield         ...          \
# id                                                             ...
# 12899             2.0  45.564010 -122.634717  28396.80         ...
# 25200             7.0  45.556750 -122.677839   2067.12         ...
# 26203            30.0  45.556965 -122.675656   1853.28         ...
# 29931             2.0  45.482782 -122.720891  13104.00         ...
# 59425             2.0  45.561805 -122.650969   1778.40         ...
#
#        bed_type_Couch  bed_type_Futon  bed_type_Pull-out Sofa  \
# id
# 12899               0               0                       0
# 25200               0               0                       0
# 26203               0               0                       0
# 29931               0               0                       0
# 59425               0               0                       0
#
#        bed_type_Real Bed  topics_description_Budget  \
# id
# 12899                  1                          0
# 25200                  1                          0
# 26203                  1                          0
# 29931                  1                          1
# 59425                  1                          0
#
#        topics_description_Business  topics_description_Luxury  price  \
# id
# 12899                            1                          0   85.0
# 25200                            1                          0   99.0
# 26203                            1                          0   99.0
# 29931                            0                          0  350.0
# 59425                            0                          1  190.0
#
#        reviews_per_month  topics_description
# id
# 12899               4.64            Business
# 25200               0.29            Business
# 26203               0.26            Business
# 29931               0.52              Budget
# 59425               0.13              Luxury
#
# [5 rows x 29 columns]

# %%
df3 = df2[['topics_description', 'price', 'reviews_per_month']].groupby(['topics_description']).mean()
df3['count'] = df2[['yield', 'topics_description']].groupby(['topics_description']).count()['yield']
df3['reviews_per_year'] = df3['reviews_per_month']*12
df3['color'] = ['R', 'G', 'B']

# %%
sns.palplot(sns.color_palette("Set2", 8))

# %%
df3.head()
# Out:
#                          price  reviews_per_month  count  reviews_per_year  \
# topics_description
# Budget              172.241379           3.484017    580         41.808207
# Business            153.361333           3.532880    750         42.394560
# Luxury              169.870897           3.762713    457         45.152560
#
#                    color
# topics_description
# Budget                 R
# Business               G
# Luxury                 B

# %%
df3.describe()
# Out:
#             price  reviews_per_month       count  reviews_per_year
# count    3.000000           3.000000    3.000000          3.000000
# mean   165.157870           3.593204  595.666667         43.118442
# std     10.284625           0.148819  147.126929          1.785827
# min    153.361333           3.484017  457.000000         41.808207
# 25%    161.616115           3.508449  518.500000         42.101383
# 50%    169.870897           3.532880  580.000000         42.394560
# 75%    171.056138           3.647797  665.000000         43.773560
# max    172.241379           3.762713  750.000000         45.152560

# %%
plt.figure(figsize=(9, 6))

# Unique category labels:
color_labels = df3['color'].unique()

# List of RGB triplets
rgb_values = sns.color_palette("Set2", 8)

# Map label to RGB
color_map = dict(zip(color_labels, rgb_values))

# Finally use the mapped values
plt.scatter(df3['reviews_per_year'], df3['price'], c=df3['color'].map(color_map), s=df3['count']*1.5)

plt.ylim([100,240])
plt.xlim([20,60])

plt.xlabel('Avg. no. of reviews / year')
plt.ylabel('Avg. price / night ($)')
plt.title('Average price and frequency of reviews by description topic', weight='bold', fontsize=14)

for i, txt in enumerate(df3.index):
    plt.annotate(txt, (df3['reviews_per_year'].iat[i]-0.3,df3['price'].iat[i]), fontsize=11, weight='bold')

# %% [markdown]
# ## Bag of words
# Most popular words

# %%
# BOW across all listings
bow = Counter(itertools.chain(*processed_corpus_description))
bow.most_common(20)
# Out:
# [('room', 1867),
#  ('private', 1696),
#  ('home', 1691),
#  ('house', 1519),
#  ('kitchen', 1364),
#  ('bed', 1295),
#  ('bedroom', 1258),
#  ('space', 1238),
#  ('apartment', 1076),
#  ('full', 1032),
#  ('neighborhood', 1016),
#  ('bathroom', 1015),
#  ('downtown', 951),
#  ('one', 934),
#  ('access', 927),
#  ('living', 923),
#  ('queen', 908),
#  ('coffee', 906),
#  ('walk', 864),
#  ('street', 844)]

# %%
list(df2)
# Out:
# ['accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'latitude',
#  'longitude',
#  'yield',
#  'property_type_Apartment',
#  'property_type_Guest suite',
#  'property_type_Guesthouse',
#  'property_type_House',
#  'property_type_Other',
#  'room_type_Entire home/apt',
#  'room_type_Private room',
#  'room_type_Shared room',
#  'bed_type_Airbed',
#  'bed_type_Couch',
#  'bed_type_Futon',
#  'bed_type_Pull-out Sofa',
#  'bed_type_Real Bed',
#  'topics_description_Budget',
#  'topics_description_Business',
#  'topics_description_Luxury',
#  'price',
#  'reviews_per_month',
#  'topics_description']

# %%
# %matplotlib inline
fig = plt.subplots(figsize=(16,16))
ax1 = plt.subplot2grid((4, 4), (0, 0))
ax2 = plt.subplot2grid((4, 4), (0, 1))
ax3 = plt.subplot2grid((4, 4), (0, 2))

ax4 = plt.subplot2grid((4, 4), (1, 0))
ax5 = plt.subplot2grid((4, 4), (1, 1))
ax6 = plt.subplot2grid((4, 4), (1, 2))

ax7 = plt.subplot2grid((4, 4), (2, 0))
# ax8 = plt.subplot2grid((4, 4), (2, 1))
# ax9 = plt.subplot2grid((4, 4), (2, 2))

#fig.suptitle('Scatterplot of numerical variables against Yield')

sns.regplot(x='accommodates', y='yield', data=df, ax=ax1, scatter_kws={'alpha':0.25})
sns.regplot(x='guests_included', y='yield', data=df, ax=ax2)
sns.regplot(x='extra_people', y='yield', data=df, ax=ax3)

sns.regplot(x='beds', y='yield', data=df, ax=ax4)
sns.regplot(x='bedrooms', y='yield', data=df, ax=ax5)
sns.regplot(x='bathrooms', y='yield', data=df, ax=ax6)

sns.regplot(x='minimum_nights', y='yield', data=df, ax=ax7)

# sns.stripplot(x='property_type', y='yield', data=df, jitter=1.0, alpha=0.25, ax=ax8)
# sns.stripplot(x='room_type', y='yield', data=df, jitter=1.0, alpha=0.25, ax=ax9)
