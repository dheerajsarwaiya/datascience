# %% [markdown]
# Objective - I am trying to experiment to reduce computation time for knn classification.
#
# I start with creating k clusters using kmean algorithm and then using centroid of these as training for knn classification.
#
# I will use Titanic Data, which I used earlier to learn about KMean

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
from sklearn.cluster import KMeans

# %%
style.use('ggplot')

# %% [markdown]
# Will use titanic data set for next step. Here is the data set overview
#
#
#
# Pclass Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
#
# survival Survival (0 = No; 1 = Yes)
#
# name Name
#
# sex Sex
#
# age Age
#
# sibsp Number of Siblings/Spouses Aboard
#
# parch Number of Parents/Children Aboard
#
# ticket Ticket Number
#
# fare Passenger Fare (British pound)
#
# cabin Cabin
#
# embarked Port of Embarkation (C = Cherbourg; Q = Queenstown; S =
# Southampton)
# boat Lifeboat
#
# body Body Identification Number
#
# home.dest Home/Destination

# %% [markdown]
# Focus on the survival column. My program will decide on the groups. I am doing flat clustering, basically dividing into two groups. Later let machine decide on the groups.

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import pandas as pd

# %% [markdown]
# I have to install xlrd package here

# %%
df = pd.read_excel('titanic.xls')
print(df.head())
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# handle non numerical data.. Drop name..

# %%
df.drop(['body','name'], 1, inplace=True)

# %%
df.convert_objects(convert_numeric=True)
# Out:
# /home/dheeraj/work/env1/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#       pclass  survived     sex      age  sibsp  parch     ticket      fare  \
# 0          1         1  female  29.0000      0      0    24160.0  211.3375
# 1          1         1    male   0.9167      1      2   113781.0  151.5500
# 2          1         0  female   2.0000      1      2   113781.0  151.5500
# 3          1         0    male  30.0000      1      2   113781.0  151.5500
# 4          1         0  female  25.0000      1      2   113781.0  151.5500
# 5          1         1    male  48.0000      0      0    19952.0   26.5500
# 6          1         1  female  63.0000      1      0    13502.0   77.9583
# ...

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# Handle non numerical data by assigning them numerical values

# %%
def handle_non_numerical_data(df):
    columns = df.columns.values
    for column in columns:
        text_digit_vals = {}
        def convert_to_int(val):
            return text_digit_vals[val]

        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            column_contents = df[column].values.tolist()
            unique_elements = set(column_contents)
            x = 0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique] = x
                    x+=1

            df[column] = list(map(convert_to_int, df[column]))

    return df

# %%
df = handle_non_numerical_data(df)
print(df.head())
# Out:
#    pclass  survived  sex      age  sibsp  parch  ticket      fare  cabin  \
# 0       1         1    0  29.0000      0      0     757  211.3375    185
# 1       1         1    1   0.9167      1      2     516  151.5500    101
# 2       1         0    0   2.0000      1      2     516  151.5500    101
# 3       1         0    1  30.0000      1      2     516  151.5500    101
# 4       1         0    0  25.0000      1      2     516  151.5500    101
#
#    embarked  boat  home.dest
# 0         0     2        143
# 1         0    17        276
# 2         0     0        276
# 3         0     0        276
# 4         0     0        276

# %%
X = np.array(df.drop(['survived'], 1).astype(float))
X = preprocessing.scale(X)
y = np.array(df['survived'])

# %%
print(len(X))
print(X.shape)
# Out:
# 1309
# (1309, 11)

# %%
clf = KMeans(n_clusters=2)
clf.fit(X)

correct = 0
for i in range(len(X)):
    predict_me = np.array(X[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = clf.predict(predict_me)
    if prediction[0] == y[i]:
        correct += 1

print(correct/len(X))
# Out:
# 0.7104660045836516

# %%
centroids = clf.cluster_centers_
labels = clf.labels_
print(centroids)
print(centroids.shape)
print(labels)
print(labels.shape)
# Out:
# [[ 0.47687743  0.11566791 -0.22349232  0.0060104  -0.02074718 -0.01477532
#   -0.341927   -0.42549635 -0.06345592 -0.19466292 -0.21522957]
#  [-1.40902152 -0.34176198  0.66034892 -0.01775881  0.06130133  0.04365639
#    1.01028582  1.25720675  0.18749212  0.57516717  0.6359351 ]]
# (2, 11)
# [1 1 1 ... 0 0 0]
# (1309,)

# %%
from sklearn import preprocessing, neighbors

# %%
knnclf = neighbors.KNeighborsClassifier(n_neighbors=2)

# %%
knnclf.fit(centroids, [0,1])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=2, p=2,
#            weights='uniform')

# %%
accuracy = knnclf.score(X, y)
print(accuracy)
# Out:
# 0.6180290297937356
